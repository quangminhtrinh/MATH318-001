# %% [markdown]
# # Exporting
# Click on the ... dots in the corner and then export to HTML or, ideally, PDF.  Direct to PDF will require a LaTeX installation, and likely an Inkscape installation.

# %% [markdown]
# # Elementary Markdown
#
# Note the number of `#`'s determines the Heading level (1,2,3,...).
# Text can be formatted as _this_ or **this**.
#
# Mathematical symbols can be included with $\alpha$ and
# $$
# f(x) = x^2
# $$

# %% [markdown]
# # Basic Arithmetic

# %%
1+1

# %%
3 * 4

# %%
4/2

# %% [markdown]
# Division returns floating point numbers even if the numbers divide.

# %%
3/2

# %%
1.0 * 3

# %%
1.0 + 4

# %%
3**2 # raising to a power

# %%
1.5**2

# %% [markdown]
# # NumPy
# Use this package to access all standard scientific calculator functions, along with arrays and matrices.

# %%
import numpy as np # import the numpy library and give it the nickname np

# %% [markdown]
# ## Functions

# %%
np.sin(1.5) # sine function

# %%
np.sin(np.pi/2) # sine of pi/2 radians

# %% [markdown]
# Note that this returns the numpy data type with the specified value.

# %%
np.float64(1.0)==1

# %% [markdown]
# To get rid of the `np.float64` type, use `item`:

# %%
np.float64(1.0).item()

# %%
np.exp(1) # e raised to the power of 1

# %%
np.sqrt(4)

# %%
np.log(10) # natural logarithm of 10

# %%
np.log10(10) # logarithm base 10 of 10

# %% [markdown]
# ## Basic Variables

# %%
x = 3
y = 4
z = x+y
z # since no ;, this will just print to the screen

# %%
print(z); # this will also print to the screen, but is more explicit

# %%
state ='PA'
city = 'Philadelphia'
print(city, state);

# %%
city + state # concatenation of strings

# %%
city +', ' + state

# %% [markdown]
# ## Arrays and Matrices

# %% [markdown]
# ### Arrays
# Access via `[]` and indexing begins at `0`

# %%
x = [1, 2, 3]
x

# %%
x[1]

# %%
x[0]

# %%
x[2]

# %%
y = ['a', 'b', 'c']
y

# %%
x+y # concatenation of lists

# %% [markdown]
# Most of the time, use NumPy arrays:

# %%
x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

# %%
x[0]

# %%
y[2]

# %%
z1 = x + 2 * y
z1

# %%
z2 = x + 2.0 * y
z2

# %%
z1.dtype

# %%
z2.dtype

# %%
x.size

# %%
x.shape

# %%
x.ndim #1D array

# %%
x * y #elementwise multiplication of the arrays

# %%
np.dot(x, y) # dot product of the two arrays

# %%
dot_product = np.dot(x, y).item()

# %% [markdown]
# The following is a NumPy data type.

# %%
type(np.dot(x, y))

# %% [markdown]
# The following is an intrinsic Python data type.

# %%
type(dot_product)

# %%
np.outer(x,y) # outer product of the two arrays

# %%
np.dot(x, y) + 13.5

# %% [markdown]
# ### Matrices

# %% [markdown]
# # Random Variables

# %% [markdown]
# ## Uniform

# %% [markdown]
# ## Gaussian

# %% [markdown]
# ## Setting the Seed

# %% [markdown]
# # LaTeX and Markdown

# %% [markdown]
# # Source Files

# %% [markdown]
# # Elementary Statistics

# %% [markdown]
# # Control Structures in Python

# %% [markdown]
# ## If-Then-Else

# %% [markdown]
# ## For Loops

# %% [markdown]
# # Functions

# %% [markdown]
# # Intro to Plotting
# This is handled by `matplotlib` pacakge.

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Line Plots

# %%
x = np.linspace(0, 10, 100) # 100 points between 0 and 10, inclusive
y = np.sin(x) # sine of each point in x

# %%
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.title('Sine Function')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# We can use LaTeX here:

# %%
plt.plot(x, y)
plt.title('Sine Function')
plt.xlabel(r'$x$') # raw string to allow for LaTeX formatting
plt.ylabel(r'$y$')
plt.show()

# %%
plt.plot(x, np.sin(x), label=r'$\sin(x)$')
plt.plot(x, np.cos(x), label=r'$\cos(x)$')
plt.title('Sine and Cosine Functions')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.legend()
plt.show()

# %%
plt.plot(x, np.sin(x), label=r'$\sin(x)$')
plt.plot(x, np.cos(x), label=r'$\cos(x)$')
plt.title('Sine and Cosine Functions')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.legend()
plt.savefig('sine_cosine_plot.png') # save the figure to a file

# %% [markdown]
# ## Scatter Plots

# %% [markdown]
# ## Histograms

# %% [markdown]
# ## Box Plots

# %% [markdown]
#  # Loading Data and Data Frames

# %% [markdown]
# ## CSV and Excel Files

# %% [markdown]
# ## Rows and Columns

# %% [markdown]
# ## Indexes

# %% [markdown]
# ## Setting Data Types

# %% [markdown]
# ## Basic Statistics

# %% [markdown]
# ## Subsetting and Filtering
